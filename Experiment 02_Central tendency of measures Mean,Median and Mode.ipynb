# %%
# Experiment no : 02

# %%
# Aim : To perform operations of getting basic statistical description of dataset

# %%
# Name : Shreya Thakare
# Roll no : 64
# Section : C
# Subject : ET1
# Date : 01/08/2025

# %%
age=[20,21,22,21,21,22,20,21,22,23,21,23,22,20,20,21,24,24]

# %%
age
# Out:
# [20, 21, 22, 21, 21, 22, 20, 21, 22, 23, 21, 23, 22, 20, 20, 21, 24, 24]

# %%
print(age)
# Out:
# [20, 21, 22, 21, 21, 22, 20, 21, 22, 23, 21, 23, 22, 20, 20, 21, 24, 24]

# %%
import statistics

# %%
a=statistics.mean(age)

# %%
a
# Out:
# 21.555555555555557

# %%
b=statistics.median(age)

# %%
b
# Out:
# 21.0

# %%
c=statistics.mode(age)

# %%
c
# Out:
# 21

# %%
import numpy as np
x=np.array([1,2,3,4,5,6,7,3,4,6,1,2,3,5,6])

# %%
x
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 3, 4, 6, 1, 2, 3, 5, 6])

# %%
print(np.mean(x))
# Out:
# 3.8666666666666667

# %%
print(np.median(x))
# Out:
# 4.0

# %%
from scipy import stats

# %%
print(stats.mode(x))
# Out:
# ModeResult(mode=np.int64(3), count=np.int64(3))

# %%
print(np.std(x))
# Out:
# 1.8571184369578824

# %%
print(np.var(x))
# Out:
# 3.4488888888888884
