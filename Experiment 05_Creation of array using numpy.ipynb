# %%
# Experiment no : 05

# %%
# Aim :Creating dimensional array

# %%
# Name : Shreya Thakare
# Roll no : 64
# Section : C
# Subject : ET1

# %%
import numpy as np

# %%
#creating 1D array
a1=np.array([10,20,30,40,])

# %%
a1
# Out:
# array([10, 20, 30, 40])

# %%
#creating2D array
a2=np.array([[11,30,20,40],[34,89,47,34]])

# %%
a2
# Out:
# array([[11, 30, 20, 40],
#        [34, 89, 47, 34]])

# %%
#creating 3D array
a3=np.matrix('11,23;33,45;67,78')

# %%
a3
# Out:
# matrix([[11, 23],
#         [33, 45],
#         [67, 78]])

# %%
#create array of 25 random integers between 20 and 23(inclusive)
arr=np.random.randint(20,24,size=25)
print(arr)
# Out:
# [21 23 23 22 22 20 21 22 23 22 23 20 21 21 22 21 20 22 22 23 22 20 23 23
#  21]
